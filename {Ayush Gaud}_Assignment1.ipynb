# %%
# Task 1 :

import numpy as np
from numpy import random

coords=random.randint(0,100,size=(1000,2))
print(coords)
# Out:
# [[71 63]
#  [34 75]
#  [49  8]
#  ...
#  [95 84]
#  [23 95]
#  [85 20]]

# %%
# Task 2 (Sub-part 1) :

import matplotlib.pyplot as plt
import numpy as np
from numpy import random

point=random.randint(0,100,size=(2,1000))
x=point[0]
y=point[1]
color=np.arange(0,1000)

plt.grid()
plt.scatter(x,y,c=color,cmap='viridis')
plt.show()

# %%
# Task 2 (Sub-part 2) :

# %%
# Task 3 (Sub-part 1) :

import numpy as np
from numpy import random

coords=random.randint(0,100,size=(1000,3))
print(coords)

# Similarly we can print coordinates for d=4,10,50,100
# Out:
# [[35 16 15]
#  [13 26 48]
#  [21 90 86]
#  ...
#  [41 14  8]
#  [82 13  2]
#  [15 77 46]]

# %%
# Task 3 (Sub-part 2) :
